# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import numpy as np

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Use 2017-2018 team statistics to visualize team's performance in this season
df = pd.read_csv('/Users/weijiaheng/Desktop/Project /2017-2018.csv')
df.head()
# Out:
#                     Team   G     MP    FG   FGA    FG%    3P   3PA    3P%  \
# 0  Golden State Warriors  82  19730  3509  6981  0.503   926  2370  0.391
# 1        Houston Rockets  82  19755  3174  6906  0.460  1256  3470  0.362
# 2   New Orleans Pelicans  82  19955  3500  7241  0.483   837  2312  0.362
# 3        Toronto Raptors  82  19830  3383  7169  0.472   968  2705  0.358
# 4    Cleveland Cavaliers  82  19730  3311  6950  0.476   981  2636  0.372
#
#      2P  ...     FT%  ORB   DRB   TRB   AST  STL  BLK   TOV    PF   PTS
# 0  2583  ...   0.815  691  2877  3568  2402  656  612  1267  1607  9304
# 1  1918  ...   0.781  739  2825  3564  1767  699  392  1135  1597  9213
# 2  2663  ...   0.772  712  2924  3636  2195  657  485  1223  1570  9161
# 3  2415  ...   0.794  800  2807  3607  1995  626  500  1095  1783  9156
# 4  2330  ...   0.779  694  2761  3455  1916  582  312  1126  1524  9091
#
# [5 rows x 24 columns]

# %%
import numpy as np
from sklearn.preprocessing import scale
labels=df[['3P%', '2P%', 'FT%', 'TRB', 'AST', 'STL','BLK','PTS']]

# %%
from sklearn import preprocessing
import pandas as pd
x = labels.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_new = pd.DataFrame(x_scaled)

# %%
df_new.columns=[list(labels)]

# %%
df_new['Team']=df['Team']
df_new.head()
# Out:
#         3P%       2P%       FT%       TRB       AST       STL       BLK  \
# 0  1.000000  1.000000  1.000000  0.483923  1.000000  0.623377  1.000000
# 1  0.491228  0.975610  0.663366  0.477492  0.209215  0.809524  0.318885
# 2  0.491228  0.756098  0.574257  0.593248  0.742217  0.627706  0.606811
# 3  0.421053  0.768293  0.792079  0.546624  0.493151  0.493506  0.653251
# 4  0.666667  0.756098  0.643564  0.302251  0.394770  0.303030  0.071207
#
#         PTS                   Team
# 0  1.000000  Golden State Warriors
# 1  0.924167        Houston Rockets
# 2  0.880833   New Orleans Pelicans
# 3  0.876667        Toronto Raptors
# 4  0.822500    Cleveland Cavaliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Plot the radar chart for Pacific Teams
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.graph_objs import *
tools.set_credentials_file(username='Derrick_Wei', api_key='7hsH9Gd5Vt7738ZAKsmI')

data = [
    go.Scatterpolar(
      r = [1.000000,1.000000,1.000000,0.483923,1.000000,0.623377,1.000000,1.000000],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Golden State Warriors'
    ),
    go.Scatterpolar(
      r = [0.192982,0.475610,0.000000,0.861736,0.435866,0.523810,0.306502,0.631667],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Los Angeles Lakers'
    ),
     go.Scatterpolar(
      r = [0.350877,0.573171,0.287129,0.532154,0.290162,0.502165,0.260062,0.694167],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Los Angeles Clippers'
    ),
    go.Scatterpolar(
      r = [0.000000,0.170732,0.267327,0.564309,0.179328,0.246753,0.250774,0.348333],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Phoenix Suns'
    ),
    go.Scatterpolar(
      r = [0.719298,0.012195,0.207921,0.141479,0.210461,0.567100,0.157895,0.000000],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Sacramento Kings'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 1]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = "")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Derrick_Wei/1.embed" height="525px" width="100%"></iframe>

# %%
# Plot the radar chart for Atlantic Teams
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.graph_objs import *
tools.set_credentials_file(username='Derrick_Wei', api_key='7hsH9Gd5Vt7738ZAKsmI')

data = [
    go.Scatterpolar(
      r = [0.614035,0.585366,0.376238,1.000000,0.774595,0.735931,0.405573,0.750000],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Philadelphia 76ers'
    ),
    go.Scatterpolar(
      r = [0.421053,0.768293,0.792079,0.546624,0.493151,0.493506,0.653251,0.876667],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Toronto Raptors'
    ),
     go.Scatterpolar(
      r = [0.754386,0.158537,0.564356,0.607717,0.302615,0.398268,0.260062,0.354167],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Boston Celtics'
    ),
    go.Scatterpolar(
      r = [0.315789,0.317073,0.722772,0.553055,0.389788,0.173160,0.408669,0.385000],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'New York Knicks'
    ),
    go.Scatterpolar(
      r = [0.385965,0.268293,0.574257,0.606109,0.425903,0.000000,0.312693,0.530833],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Brooklyn Nets'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 1]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = "")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Derrick_Wei/1.embed" height="525px" width="100%"></iframe>

# %%
# Plot the radar chart for Middle Teams
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.graph_objs import *
tools.set_credentials_file(username='Derrick_Wei', api_key='7hsH9Gd5Vt7738ZAKsmI')

data = [
    go.Scatterpolar(
      r = [0.666667,0.756098,0.643564,0.302251,0.394770,0.303030,0.071207,0.822500],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Cleveland Cavaliers'
    ),
    go.Scatterpolar(
      r = [0.614035,0.426829,0.643564,0.329582,0.273973,0.904762,0.157895,0.460000],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Indiana Pacers'
    ),
     go.Scatterpolar(
      r = [0.368421,0.000000,0.445545,0.636656,0.403487,0.493506,0.000000,0.280000],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Chicago Bulls'
    ),
    go.Scatterpolar(
      r = [0.684211,0.121951,0.306931,0.512862,0.334994,0.502165,0.086687,0.337500],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Detroit Pistons'
    ),
    go.Scatterpolar(
      r = [0.368421,0.646341,0.683168,0.000000,0.381071,0.909091,0.476780,0.522500],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Milwaukee Bucks'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 1]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = "")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Derrick_Wei/1.embed" height="525px" width="100%"></iframe>

# %%
# Plot the radar chart for Southwest Teams
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.graph_objs import *
tools.set_credentials_file(username='Derrick_Wei', api_key='7hsH9Gd5Vt7738ZAKsmI')

data = [
    go.Scatterpolar(
      r = [0.456140,0.219512,0.485149,0.186495,0.322540,0.285714,0.065015,0.238333],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Dallas Mavericks'
    ),
    go.Scatterpolar(
      r = [0.491228,0.975610,0.663366,0.477492,0.209215,0.809524,0.318885,0.924167],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Houston Rockets'
    ),
     go.Scatterpolar(
      r = [0.315789,0.097561,0.712871,0.090032,0.209215,0.437229,0.331269,0.034167],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Memphis Grizzlies'
    ),
    go.Scatterpolar(
      r = [0.491228,0.756098,0.574257,0.593248,0.742217,0.627706,0.606811,0.880833],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'New Orleans Pelicans'
    ),
    go.Scatterpolar(
      r = [0.315789,0.256098,0.574257,0.577170,0.334994,0.502165,0.529412,0.266667],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'San Antonio Spurs'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 1]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = "")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Derrick_Wei/1.embed" height="525px" width="100%"></iframe>

# %%
# Plot the radar chart for Northwest Teams
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.graph_objs import *
tools.set_credentials_file(username='Derrick_Wei', api_key='7hsH9Gd5Vt7738ZAKsmI')

data = [
    go.Scatterpolar(
      r = [0.403509,0.500000,0.891089,0.279743,0.326276,0.766234,0.173375,0.730000],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Minnesota Timberwolves'
    ),
    go.Scatterpolar(
      r = [0.561404,0.451220,0.643564,0.450161,0.298879,0.848485,0.405573,0.363333],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Utah Jazz'
    ),
     go.Scatterpolar(
      r = [0.561404,0.182927,0.851485,0.741158,0.000000,0.264069,0.414861,0.464167],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Portland Trail Blazers'
    ),
    go.Scatterpolar(
      r = [0.649123,0.573171,0.524752,0.615756,0.572852,0.497835,0.356037,0.763333],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Denver Nuggets'
    ),
    go.Scatterpolar(
      r = [0.350877,0.329268,0.019802,0.688103,0.188045,1.000000,0.380805,0.616667],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Oklahoma City Thunder'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 1]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = "")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Derrick_Wei/1.embed" height="525px" width="100%"></iframe>

# %%
# Plot the radar chart for Southeast Teams
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import tools
from plotly.graph_objs import *
tools.set_credentials_file(username='Derrick_Wei', api_key='7hsH9Gd5Vt7738ZAKsmI')

data = [
    go.Scatterpolar(
      r = [0.456140,0.365854,0.405941,0.477492,0.327522,0.467532,0.458204,0.313333],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Miami Heat'
    ),
    go.Scatterpolar(
      r = [0.456140,0.207317,0.702970,0.271704,0.432130,0.545455,0.182663,0.309167],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Atlanta Hawks'
    ),
     go.Scatterpolar(
      r = [0.298246,0.317073,0.425743,0.236334,0.400996,0.476190,0.343653,0.312500],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Orlando Magic'
    ),
    go.Scatterpolar(
      r = [0.719298,0.365854,0.574257,0.432476,0.580324,0.575758,0.198142,0.531667],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Washington Wizards'
    ),
    go.Scatterpolar(
      r = [0.614035,0.109756,0.326733,0.741158,0.212951,0.203463,0.260062,0.641667],
      theta = ['3P%','2P%','FT%', 'TRB', 'AST', 'STL','BLK','PTS','3P%'],
      fill = 'toself',
      name = 'Charlotte Hornets'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 1]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = "")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Derrick_Wei/1.embed" height="525px" width="100%"></iframe>
